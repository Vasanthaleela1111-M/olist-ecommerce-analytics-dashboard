# %% [markdown]
# # 02. Master Analytical Dataset Construction & Validation
# **Olist Brazilian E-Commerce Analytics Hackathon**
#
# This notebook executes the end-to-end master order dataset pipeline (**1 row = 1 order grain**, 99,441 rows), runs the **6 automated validation checks**, and exports `outputs/exports/master_orders.csv`.

# %%
import os
import sys
import pandas as pd

sys.path.append('..')
from src.build_master import build_master_orders_dataset

# Build master dataset & execute automated validation checks
master_df = build_master_orders_dataset('../data')
print(f'Master Dataset Shape: {master_df.shape}')
display(master_df.head())
# Out:
# Loading 9 raw CSV datasets from ../data...
#  Loaded 'orders': 99,441 rows x 8 cols
#  Loaded 'order_items': 112,650 rows x 6 cols
#  Loaded 'order_payments': 103,886 rows x 5 cols
#  Loaded 'order_reviews': 100,000 rows x 7 cols
#  Loaded 'customers': 99,441 rows x 5 cols
#  Loaded 'products': 32,951 rows x 9 cols
#  Loaded 'sellers': 3,095 rows x 4 cols
#  Loaded 'geolocation': 1,000,163 rows x 5 cols
#  Loaded 'category_translation': 71 rows x 2 cols
#
# --- Validating Schema & Key Integrity across all 9 Datasets ---
# Schema & Primary Key Validation: ALL CHECKS PASSED PASSED!
# Cleaning timestamp columns...
# Cleaning category translations and text fields...
# Aggregating order_items to order_id grain...
# Aggregating order_payments to order_id grain...
# Deduplicating order_reviews to latest review per order_id...
# Aggregating geolocation by ZIP prefix...
# Building master order spine joins...
# Executing feature engineering transformations...
#
# ...
