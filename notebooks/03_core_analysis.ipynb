# %% [markdown]
# # 03. Core Analytical Questions & Evidence Calculations
# **Olist Brazilian E-Commerce Analytics Hackathon**
#
# This notebook executes numerical calculations for the six core questions using `master_orders.csv`.

# %%
import os
import sys
import pandas as pd

sys.path.append('..')
from src.metrics import compute_marketplace_metrics, compute_delivery_metrics, compute_seller_pareto_metrics

master_df = pd.read_csv('../outputs/exports/master_orders.csv')
print('1. Marketplace Metrics:', compute_marketplace_metrics(master_df))
print('2. Delivery Metrics:', compute_delivery_metrics(master_df))
print('3. Seller Pareto Metrics:', compute_seller_pareto_metrics(master_df))
# Out:
# 1. Marketplace Metrics: {'total_gmv_rs': np.float64(13591643.7), 'total_freight_rs': np.float64(2251909.54), 'total_revenue_rs': np.float64(15843553.24), 'total_orders': 99441, 'item_aov_rs': np.float64(137.75), 'total_aov_rs': np.float64(160.58)}
# 2. Delivery Metrics: {'total_delivered_orders': 96470, 'ontime_rate_pct': np.float64(91.89), 'late_rate_pct': np.float64(8.11), 'avg_actual_lead_time_days': np.float64(12.56), 'avg_estimated_lead_time_days': np.float64(23.74), 'avg_review_score_ontime': np.float64(4.28), 'avg_review_score_late': np.float64(2.54), 'pct_1star_ontime': np.float64(6.82), 'pct_1star_late': np.float64(46.73), 'delay_review_corr_r': np.float64(-0.2692)}
# 3. Seller Pareto Metrics: {'total_active_sellers': 3085, 'top_1pct_gmv_share_pct': np.float64(26.04), 'top_5pct_gmv_share_pct': np.float64(53.26), 'top_10pct_gmv_share_pct': np.float64(67.46), 'top_20pct_gmv_share_pct': np.float64(82.6)}
